# %%
import re
import string
from collections import Counter
import numpy as np

# %%
def read_corpus(filename):
    with open(filename, "r") as file:
        lines = file.readlines()
    words = []
    for line in lines:
        words += re.findall(r'\w+', line.lower())

    return words

# %%
words = read_corpus("data/les_miserables_victor_hugo.txt")
print(f"There are {len(words)} total words in the corpus")
# Out:
# There are 122865 total words in the corpus

# %%
vocabs = set(words)
print(f"There are {len(vocabs)} unique words in the vocabulary")
# Out:
# There are 12866 unique words in the vocabulary

# %%
word_counts = Counter(words)
print(word_counts["love"])
# Out:
# 484

# %%
total_word_count = float(sum(word_counts.values()))
word_probas = {word: word_counts[word] / total_word_count for word in word_counts.keys()}

# %%
print(word_probas["love"])
# Out:
# 0.000433853090530977

# %%
def split(word):
  return [(word[:i], word[i:]) for i in range(len(word) + 1)]

# %%
print(split("trash"))
# Out:
# [('', 'trash'), ('t', 'rash'), ('tr', 'ash'), ('tra', 'sh'), ('tras', 'h'), ('trash', '')]

# %%
def delete(word):
  return [l + r[1:] for l,r in split(word) if r]

# %%
print(delete("trash"))
# Out:
# ['rash', 'tash', 'trsh', 'trah', 'tras']

# %%
def swap(word):
  return [l + r[1] + r[0] + r[2:] for l, r in split(word) if len(r)>1]

# %%
print(swap("trash"))
# Out:
# ['rtash', 'tarsh', 'trsah', 'trahs']

# %%
string.ascii_lowercase
# Out:
# 'abcdefghijklmnopqrstuvwxyz'

# %%
def replace(word):
  letters = string.ascii_lowercase
  return [l + c + r[1:] for l, r in split(word) if r for c in letters]

# %%
print(replace("trash"))
# Out:
# ['arash', 'brash', 'crash', 'drash', 'erash', 'frash', 'grash', 'hrash', 'irash', 'jrash', 'krash', 'lrash', 'mrash', 'nrash', 'orash', 'prash', 'qrash', 'rrash', 'srash', 'trash', 'urash', 'vrash', 'wrash', 'xrash', 'yrash', 'zrash', 'taash', 'tbash', 'tcash', 'tdash', 'teash', 'tfash', 'tgash', 'thash', 'tiash', 'tjash', 'tkash', 'tlash', 'tmash', 'tnash', 'toash', 'tpash', 'tqash', 'trash', 'tsash', 'ttash', 'tuash', 'tvash', 'twash', 'txash', 'tyash', 'tzash', 'trash', 'trbsh', 'trcsh', 'trdsh', 'tresh', 'trfsh', 'trgsh', 'trhsh', 'trish', 'trjsh', 'trksh', 'trlsh', 'trmsh', 'trnsh', 'trosh', 'trpsh', 'trqsh', 'trrsh', 'trssh', 'trtsh', 'trush', 'trvsh', 'trwsh', 'trxsh', 'trysh', 'trzsh', 'traah', 'trabh', 'trach', 'tradh', 'traeh', 'trafh', 'tragh', 'trahh', 'traih', 'trajh', 'trakh', 'tralh', 'tramh', 'tranh', 'traoh', 'traph', 'traqh', 'trarh', 'trash', 'trath', 'trauh', 'travh', 'trawh', 'traxh', 'trayh', 'trazh', 'trasa', 'trasb', 'trasc', 'trasd', 'trase', 'trasf', 'trasg', 'trash', 'trasi', 'trasj', 'trask', 'trasl', 'trasm', 'trasn', 'traso', 'trasp', 'trasq', 'trasr', 'trass', 'trast', 'trasu', 'trasv', 'trasw', 'trasx', 'trasy', 'trasz']

# %%
def insert(word):
  letters = string.ascii_lowercase
  return [l + c + r for l, r in split(word) for c in letters]

# %%
print(insert("trash"))
# Out:
# ['atrash', 'btrash', 'ctrash', 'dtrash', 'etrash', 'ftrash', 'gtrash', 'htrash', 'itrash', 'jtrash', 'ktrash', 'ltrash', 'mtrash', 'ntrash', 'otrash', 'ptrash', 'qtrash', 'rtrash', 'strash', 'ttrash', 'utrash', 'vtrash', 'wtrash', 'xtrash', 'ytrash', 'ztrash', 'tarash', 'tbrash', 'tcrash', 'tdrash', 'terash', 'tfrash', 'tgrash', 'thrash', 'tirash', 'tjrash', 'tkrash', 'tlrash', 'tmrash', 'tnrash', 'torash', 'tprash', 'tqrash', 'trrash', 'tsrash', 'ttrash', 'turash', 'tvrash', 'twrash', 'txrash', 'tyrash', 'tzrash', 'traash', 'trbash', 'trcash', 'trdash', 'treash', 'trfash', 'trgash', 'trhash', 'triash', 'trjash', 'trkash', 'trlash', 'trmash', 'trnash', 'troash', 'trpash', 'trqash', 'trrash', 'trsash', 'trtash', 'truash', 'trvash', 'trwash', 'trxash', 'tryash', 'trzash', 'traash', 'trabsh', 'tracsh', 'tradsh', 'traesh', 'trafsh', 'tragsh', 'trahsh', 'traish', 'trajsh', 'traksh', 'tralsh', 'tramsh', 'transh', 'traosh', 'trapsh', 'traqsh', 'trarsh', 'trassh', 'tratsh', 'traush', 'travsh', 'trawsh', 'traxsh', 'traysh', 'trazsh', 'trasah', 'trasbh', 'trasch', 'trasdh', 'traseh', 'trasfh', 'trasgh', 'trashh', 'trasih', 'trasjh', 'traskh', 'traslh', 'trasmh', 'trasnh', 'trasoh', 'trasph', 'trasqh', 'trasrh', 'trassh', 'trasth', 'trasuh', 'trasvh', 'traswh', 'trasxh', 'trasyh', 'traszh', 'trasha', 'trashb', 'trashc', 'trashd', 'trashe', 'trashf', 'trashg', 'trashh', 'trashi', 'trashj', 'trashk', 'trashl', 'trashm', 'trashn', 'trasho', 'trashp', 'trashq', 'trashr', 'trashs', 'trasht', 'trashu', 'trashv', 'trashw', 'trashx', 'trashy', 'trashz']

# %%
def edit1(word):
  return set(delete(word) + swap(word) + replace(word) + insert(word))

# %%
print(edit1("trash"))
# Out:
# {'trath', 'trasu', 'frash', 'ttash', 'trash', 'trabsh', 'irash', 'trosh', 'qrash', 'otrash', 'vtrash', 'tresh', 'ttrash', 'tgrash', 'traskh', 'trasth', 'trasuh', 'trbsh', 'trasb', 'trsh', 'tyrash', 'ptrash', 'taash', 'mrash', 'twash', 'mtrash', 'trpash', 'trasjh', 'trashd', 'trask', 'trasdh', 'trasho', 'traswh', 'tkash', 'torash', 'tsrash', 'trashj', 'trashw', 'brash', 'traush', 'rtash', 'trasih', 'traso', 'trashc', 'tfash', 'trjsh', 'srash', 'trarh', 'trass', 'rrash', 'teash', 'troash', 'trsah', 'travsh', 'terash', 'trcash', 'trjash', 'trush', 'trbash', 'trase', 'trrsh', 'trhash', 'trasph', 'trashb', 'tbrash', 'trashl', 'txash', 'trawsh', 'trahs', 'tbash', 'trlsh', 'tprash', 'grash', 'trnsh', 'transh', 'trasyh', 'triash', 'trashi', 'tkrash', 'trxash', 'traosh', 'tash', 'trasv', 'prash', 'trasf', 'trzash', 'trasp', 'trashq', 'trfsh', 'traszh', 'trcsh', 'trashx', 'erash', 'trgash', 'drash', 'krash', 'trasfh', 'traeh', 'jrash', 'trauh', 'tvrash', 'ntrash', 'trssh', 'trasn', 'trafh', 'tjrash', 'trkash', 'trasm', 'traph', 'trasg', 'trasc', 'trasi', 'trgsh', 'traash', 'tradsh', 'xtrash', 'tranh', 'traish', 'trashv', 'trasd', 'tmash', 'trasrh', 'tgash', 'utrash', 'tragsh', 'trabh', 'tryash', 'trafsh', 'ktrash', 'trashr', 'trhsh', 'trayh', 'traqh', 'tjash', 'trashs', 'traseh', 'tcash', 'traslh', 'traesh', 'tlash', 'tpash', 'tramsh', 'trashk', 'etrash', 'traksh', 'trashz', 'twrash', 'trasxh', 'trwsh', 'tqrash', 'trahsh', 'tras', 'trmsh', 'tyash', 'wtrash', 'atrash', 'trassh', 'trksh', 'trasa', 'trashm', 'trashy', 'trazh', 'trdash', 'trawh', 'trasx', 'trlash', 'treash', 'tfrash', 'trach', 'traysh', 'trzsh', 'wrash', 'trasr', 'xrash', 'trasnh', 'traxh', 'trasha', 'turash', 'txrash', 'orash', 'trasht', 'tnrash', 'arash', 'itrash', 'trasw', 'truash', 'gtrash', 'tiash', 'trashp', 'trrash', 'lrash', 'trasbh', 'trashg', 'trarsh', 'trmash', 'trtash', 'rtrash', 'tnash', 'tcrash', 'tmrash', 'tirash', 'trapsh', 'trasoh', 'trashf', 'dtrash', 'tarash', 'nrash', 'traah', 'jtrash', 'trtsh', 'trah', 'ytrash', 'trqash', 'trwash', 'thrash', 'trasgh', 'traqsh', 'trasvh', 'trashn', 'trnash', 'zrash', 'tzash', 'trahh', 'tlrash', 'vrash', 'trpsh', 'trasqh', 'traoh', 'trfash', 'tdrash', 'ltrash', 'tzrash', 'trashh', 'tralh', 'htrash', 'trvash', 'tdash', 'tralsh', 'toash', 'yrash', 'tuash', 'tqash', 'rash', 'trast', 'trasz', 'trasq', 'trish', 'tradh', 'tratsh', 'urash', 'trvsh', 'thash', 'crash', 'tsash', 'trxsh', 'trasj', 'ctrash', 'qtrash', 'strash', 'btrash', 'tarsh', 'hrash', 'tvash', 'trysh', 'traih', 'trajh', 'ztrash', 'traxsh', 'ftrash', 'tramh', 'trasmh', 'trajsh', 'trdsh', 'trasl', 'trazsh', 'trashu', 'trasy', 'tragh', 'trashe', 'trasch', 'trqsh', 'tracsh', 'trsash', 'trakh', 'trasah', 'travh'}

# %%
def edit2(word):
  return set(e2 for e1 in edit1(word) for e2 in edit1(e1))

# %%
print(edit2("trash"))
# Out:
# {'tryashs', 'trkasha', 'tdarash', 'tashr', 'urask', 'trasnmh', 'trxsch', 'tvrasv', 'traedsh', 'trqsr', 'tdraszh', 'krasdh', 'trcshp', 'tirasph', 'tgasv', 'vrasah', 'rteash', 'trpadh', 'trlwh', 'tkrcash', 'tfrwsh', 'zrajsh', 'trfaih', 'stvash', 'ftrasjh', 'tiaph', 'tlazh', 'trkasah', 'tvtrash', 'transhn', 'trvsf', 'traspl', 'dmtrash', 'trxeash', 'tcrarh', 'trkshp', 'ytrasy', 'teraih', 'thashm', 'trasdho', 'tvyash', 'gash', 'traxv', 'zqtrash', 'mrashj', 'wtrasm', 'tjrasah', 'truso', 'trgahh', 'vrarsh', 'truzash', 'traysa', 'trjhsh', 'tzbrash', 'fctrash', 'wtcash', 'vrashp', 'tuamh', 'otrashr', 'ztraso', 'htrasj', 'trfasj', 'trwaseh', 'tyrasth', 'lnrash', 'trawfsh', 'etrasbh', 'turasyh', 'trgsx', 'lrasfh', 'trauy', 'tbrdsh', 'htmrash', 'tirasnh', 'traswhp', 'yerash', 'trctsh', 'tmirash', 'trijsh', 'tlrasph', 'trfasp', 'trssf', 'tttash', 'tjach', 'trbsoh', 'triavsh', 'ltrasx', 'trpqh', 'itrassh', 'trapsrh', 'uttrash', 'tratshh', 'tvhrash', 'traxch', 'tgraxsh', 'sbash', 'troashc', 'trasvqh', 'utrashs', 'trshz', 'tjass', 'tvrsash', 'traewsh', 'traszhf', 'trnhs', 'trisht', 'prasd', 'traphp', 'traeqh', 'turashh', 'trovsh', 'trazht', 'traauh', 'jrahh', 'xraih', 'tvzash', 'ptrasoh', 'trabhy', 'odash', 'etrahh', 'trgasp', 'tanrsh', 'torfsh', 'hrashl', 'trasyy', 'ktrashb', 'turasht', 'trushm', 'trasbhp', 'uthrash', 'tregh', 'trysx', 'tfrasc', 'trzhash', 'btrbsh', 'twasmh', 'trkasnh', 'tsaslh', 'trasrqh', 'taashc', 'vttrash', 'trzasah', 'treswh', 'trcasah', 'tramrh', 'tmagh', 'tgraah', 'trashu', 'drzsh', 'trqasr', 'traahd', 'qtyash', 'trrsah', 'gkash', 'trajsih', 'tmranh', 'tyrasjh', 'tvadh', 'trqsd', 'tbashn', 'trajgh', 'trebash', 'trasvj', 'ukash', 'trsaih', 'toaoh', 'tnqrash', 'ftaash', 'ltrasnh', 'teerash', 'tyazsh', 'tmask', 'trgashc', 'ttasgh', 'trpcash', 'iradsh', 'trfasf', 'trmsu', 'tralo', 'trahjh', 'trysih', 'tprawsh', 'tyesh', 'trxsy', 'ztratsh', 'tklrash', 'tradsfh', 'ztrdash', 'transrh', 'txrayh', 'trnsgh', 'friash', 'trxashj', 'rtasph', 'tradsrh', 'metrash', 'torasmh', 'bterash', 'trahshv', 'etrayh', 'htras', 'trasdqh', 'traat', 'tsrasu', 'ornsh', 'taprash', 'trbach', 'ltdrash', 'truosh', 'trasbhg', 'tnrjsh', 'trtashf', 'trudsh', 'trhashj', 'htrashi', 'tsrrash', 'terasm', 'txirash', 'trayh', 'gtprash', 'tracn', 'tktrash', 'trasnxh', 'trashju', 'tqrnash', 'tris', 'tgdsh', 'tctash', 'trghsh', 'orsh', 'trsahf', 'przsh', 'tirasah', 'eraqsh', 'grashl', 'txasv', 'tgraoh', 'tkush', 'fraosh', 'trcshh', 'presh', 'trejsh', 'tqrashd', 'tralsqh', 'kxrash', 'tmashq', 'travbh', 'vrayh', 'tfbash', 'resh', 'tlraso', 'trqaqh', 'tirasha', 'tpralh', 'jtrach', 'tfagsh', 'tratshu', 'trrshr', 'trxshp', 'dramsh', 'dtrvsh', 'trsasj', 'ltrasth', 'hsash', 'tsraih', 'tarakh', 'tzhash', 'traskth', 'trnvsh', 'tratlsh', 'trakslh', 'trasthf', 'txbrash', 'yrasoh', 'tmayh', 'grvash', 'krawh', 'wtraskh', 'trgaqsh', 'ctruash', 'trasgg', 'tasd', 'draish', 'evtrash', 'traqp', 'toasha', 'tprah', 'tcrasxh', 'tsansh', 'ptrasgh', 'drlsh', 'rralsh', 'tragbsh', 'trsal', 'trqalsh', 'pntrash', 'traidsh', 'traoshi', 'trfaqsh', 'trayf', 'trasxhu', 'qlash', 'xrarh', 'vtrdsh', 'tracshn', 'ktrashj', 'qtrsh', 'taoh', 'prasp', 'trasavh', 'etrasx', 'jtrasnh', 'rtjash', 'htrrsh', 'grasu', 'trazslh', 'iwtrash', 'trjgsh', 'urzash', 'vjrash', 'prach', 'tyaih', 'trpfh', 'trasqth', 'trashpr', 'vraskh', 'trjkash', 'tbaesh', 'troshl', 'ftrasg', 'surash', 'tceash', 'yrazh', 'trashjo', 'trasmht', 'tqaxsh', 'zraish', 'tgasb', 'craxsh', 'trashmy', 'gtrasph', 'tcmsh', 'trasrth', 'trqmash', 'trasnl', 'tresrh', 'itrasah', 'tvrashi', 'vrxash', 'trasbx', 'ftrasf', 'tjrysh', 'tyrasm', 'traseqh', 'trfansh', 'trwshj', 'btrah', 'rrasoh', 'prjash', 'trglh', 'crasah', 'ytrsah', 'trwsw', 'truaxsh', 'tvrashx', 'tfas', 'trcmash', 'otrasg', 'txacsh', 'vtrath', 'tqaesh', 'trsasp', 'trauhv', 'trnashg', 'trqshj', 'trfaash', 'mash', 'srasn', 'irsash', 'mtrasxh', 'trdashd', 'jtrafsh', 'tcrahs', 'tnasuh', 'trsuah', 'turcsh', 'trakg', 'trosht', 'tracjsh', 'dramh', 'pmrash', 'trmsh', 'truasd', 'tpjash', 'tranqsh ...

# %%
def correct_spelling(word, vocabulary, word_probabilities):
  if word in vocabulary:
    print(f"{word} is already correctly spelt")
    return 

  suggestions = edit1(word) or edit2(word) or [word]
  best_guesses = [w for w in suggestions if w in vocabulary]
  return [(w, word_probabilities[w]) for w in best_guesses]

# %%
word = "famile"
corrections = correct_spelling(word, vocabs, word_probas)

if corrections:
  print(corrections)
  probs = np.array([c[1] for c in corrections])
  best_ix = np.argmax(probs)
  correct = corrections[best_ix][0]
  print(f"{correct} is suggested for {word}")
# Out:
# [('family', 0.0001882420434122008), ('famine', 2.6891720487457255e-06)]
# family is suggested for famile

# %%
class SpellChecker(object):

  def __init__(self, corpus_file_path):
    with open(corpus_file_path, "r") as file:
      lines = file.readlines()
      words = []
      for line in lines:
        words += re.findall(r'\w+', line.lower())

    self.vocabs = set(words)
    self.word_counts = Counter(words)
    total_words = float(sum(self.word_counts.values()))
    self.word_probas = {word: self.word_counts[word] / total_words for word in self.vocabs}

  def _level_one_edits(self, word):
    letters = string.ascii_lowercase
    splits = [(word[:i], word[i:]) for i in range(len(word) + 1)]
    deletes = [l + r[1:] for l,r in splits if r]
    swaps = [l + r[1] + r[0] + r[2:] for l, r in splits if len(r)>1]
    replaces = [l + c + r[1:] for l, r in splits if r for c in letters]
    inserts = [l + c + r for l, r in splits for c in letters] 

    return set(deletes + swaps + replaces + inserts)

  def _level_two_edits(self, word):
    return set(e2 for e1 in self._level_one_edits(word) for e2 in self._level_one_edits(e1))

  def check(self, word):
    candidates = self._level_one_edits(word) or self._level_two_edits(word) or [word]
    valid_candidates = [w for w in candidates if w in self.vocabs]
    return sorted([(c, self.word_probas[c]) for c in valid_candidates], key=lambda tup: tup[1], reverse=True)

# %%
checker = SpellChecker("./big.txt")

# %%
checker.check("sentense")
# Out:
# [('sentence', 2.3306157755796287e-05)]
